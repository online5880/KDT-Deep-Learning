# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from PIL import Image
import cv2

# 1. 모델 불러오기
model = load_model('./MobileNetV2_binary_modify.keras')

# 2. 테스트 이미지 파일 경로 설정
test_dir = './dataset/horse-or-human/test/'
# 테스트 이미지가 있는 폴더 경로
image_size = (224, 224)  # 모델에 맞는 이미지 크기, 필요시 변경
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 322 variables whereas the saved optimizer has 326 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# 3. 테스트 이미지 불러오기 및 전처리
def load_and_preprocess_image(img_path, target_size):
    try:
        # 이미지를 열고 강제로 RGB로 변환 (그레이스케일 이미지를 3차원으로 처리)
        img = Image.open(img_path).convert('RGB')
        
        # 이미지 크기 조정
        img = img.resize(target_size)
        
        # 이미지를 Numpy 배열로 변환 후 0-1 범위로 정규화
        img_array = np.array(img) / 255.0
        
        # 4차원 확장 (batch 차원 추가)
        img_array = np.expand_dims(img_array, axis=0)
        
        return img_array
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")
        return None

# 4. 테스트 이미지와 레이블 불러오기
test_images = []
test_labels = []  # 실제 레이블 (0: horse, 1: human)
image_paths = [f for f in os.listdir(test_dir) if f.lower().endswith(('jpg', 'jpeg', 'png', 'webp'))]  # 이미지 파일만 선택

for img_path in image_paths:
    if 'horse' in img_path:  # 이미지 파일 이름에 'horse'이 포함된 경우
        test_labels.append(0)  # horse는 0
    elif 'human' in img_path:  # 이미지 파일 이름에 'human'이 포함된 경우
        test_labels.append(1)  # human은 1

    # 이미지 전처리
    img_array = load_and_preprocess_image(os.path.join(test_dir, img_path), image_size)
    if img_array is not None:
        test_images.append(img_array)

# Numpy 배열로 변환
if test_images:
    test_images = np.vstack(test_images)
    test_labels = np.array(test_labels)
else:
    print("No valid images were found.")

# %%
# 이미지 전처리 및 누락된 이미지 확인
test_images = []
test_labels = []  # 실제 레이블 (0: horse, 1: human)

for img_path in image_paths:
    if 'horse' in img_path:
        test_labels.append(0)  # horse는 0
    elif 'human' in img_path:
        test_labels.append(1)  # human은 1

    img_array = load_and_preprocess_image(os.path.join(test_dir, img_path), image_size)
    
    if img_array is not None and img_array.shape == (1, image_size[0], image_size[1], 3):  # 4차원 배열 확인
        test_images.append(img_array)
    else:
        print(f"Skipping image due to processing error: {img_path}")

print(f"Processed images: {len(test_images)}, Processed labels: {len(test_labels)}")
# Out:
# Processed images: 200, Processed labels: 200

# %%
# 5. 예측 수행
# 먼저 test_images를 Numpy 배열로 변환
test_images = np.vstack(test_images)  # 여기가 중요! 배치로 묶어야 함

# 이제 모델에 올바르게 예측을 요청할 수 있음
predictions = model.predict(test_images)  # 배치 입력으로 예측 수행
predicted_labels = np.argmax(predictions, axis=1)  # 클래스별 확률에서 가장 높은 클래스 선택

# 예측된 레이블과 실제 레이블의 개수 확인
print(f"Number of test labels: {len(test_labels)}")
print(f"Number of predicted labels: {len(predicted_labels)}")

# 레이블 개수가 일치하지 않을 때 경고 메시지 출력
if len(test_labels) != len(predicted_labels):
    print("Mismatch in label counts!")
    print(f"Test labels: {len(test_labels)}, Predicted labels: {len(predicted_labels)}")
else:
    # 6. 성능 지표 계산 (개수가 일치할 때만 계산)
    accuracy = accuracy_score(test_labels, predicted_labels)
    precision = precision_score(test_labels, predicted_labels)
    recall = recall_score(test_labels, predicted_labels)
    f1 = f1_score(test_labels, predicted_labels)
    conf_matrix = confusion_matrix(test_labels, predicted_labels)

    # 성능 지표 출력
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1-Score: {f1}")
    print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 778ms/step
# Number of test labels: 200
# Number of predicted labels: 200
# Accuracy: 0.5
# Precision: 0.0
# Recall: 0.0
# F1-Score: 0.0
# Confusion Matrix:
# [[100   0]
#  [100   0]]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# 혼동 행렬 시각화 (Optional)
def plot_confusion_matrix(cm, classes):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')

# %%
# ROC-AUC는 이진 레이블이 필요하므로 이를 위해 라벨을 변환
lb = LabelBinarizer()
test_labels_binary = lb.fit_transform(test_labels)
predictions_binary = lb.transform(predicted_labels)
roc_auc = roc_auc_score(test_labels_binary, predictions_binary)

# 7. 결과 출력
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")
print("Confusion Matrix:")
print(conf_matrix)


class_names = ['Horse', 'Human']
plot_confusion_matrix(conf_matrix, class_names)
plt.show()
# Out:
# Accuracy: 0.5000
# Precision: 0.0000
# Recall: 0.0000
# F1-Score: 0.0000
# ROC-AUC: 0.5000
# Confusion Matrix:
# [[100   0]
#  [100   0]]

# %%
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow import keras

# 1. 모델 불러오기
model = keras.models.load_model('./MobileNetV2_binary_modify.keras')

# 테스트 이미지 경로
dlist = './dataset/horse-or-human/test/'
predict_list = [f for f in os.listdir(dlist) if f.lower().endswith(('jpg', 'jpeg', 'png', 'webp'))]  # 이미지 파일 목록
print(f"테스트 이미지 파일 목록: {predict_list}")

# 실제 레이블 설정 (파일 이름에 따라 설정)
true_labels = []
for file_name in predict_list:
    if "human" in file_name or "사람" in file_name:  # 사람을 나타내는 파일명에 따라 레이블 설정
        true_labels.append(1)  # 사람 -> 1
    elif "horse" in file_name or "말" in file_name:  # 말을 나타내는 파일명에 따라 레이블 설정
        true_labels.append(0)  # 말 -> 0

# 이미지 전처리 함수 정의
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    if image is not None:
        resized_img = cv2.resize(image, (224, 224))  # MobileNetV2의 입력 크기
        return resized_img.astype('float32') / 255.0  # 정규화
    else:
        print(f"이미지 로드 실패: {image_path}")
        return None

# 이미지 전처리 및 예측 준비
img = []
for i in predict_list:
    img_path = os.path.join(dlist, i)
    processed_img = preprocess_image(img_path)
    
    if processed_img is not None:
        img.append(processed_img)

# 이미지가 정상적으로 로드되었는지 확인
if len(img) == 0:
    print("이미지를 불러오지 못했습니다. 경로를 확인하세요.")
else:
    img = np.array(img)  # 리스트를 numpy 배열로 변환

    # 분류 예측
    predictions = model.predict(img)  # 이미지에 대한 예측값
    predicted_labels = (predictions >= 0.5).astype(int).flatten()  # 임계값 설정 및 예측 결과 처리

    # 예측 결과 출력 및 정확도 계산
    correct_count = 0
    for idx, prediction in enumerate(predicted_labels):
        file_name = predict_list[idx]
        true_label = true_labels[idx]
        label_str = "사람" if prediction == 1 else "말"
        correct_count += 1 if prediction == true_label else 0  # 정답 카운트

        print(f"{file_name}: 예측 - {label_str}, 실제 - {'사람' if true_label == 1 else '말'}")

    # 전체 맞춘 비율 (정확도) 계산
    accuracy = correct_count / len(predicted_labels)
    print(f"\n전체 맞춘 비율(정확도): {accuracy * 100:.2f}%")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 322 variables whereas the saved optimizer has 326 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 테스트 이미지 파일 목록: ['human_037.jpg', 'human_023.jpg', 'horse_029.jpg', 'horse_001.jpg', 'horse_015.jpg', 'horse_014.jpg', 'horse_028.jpg', 'human_022.jpg', 'human_036.jpg', 'human_008.jpg', 'human_020.jpg', 'human_034.jpg', 'horse_016.jpg', 'horse_002.jpg', 'horse_003.jpg', 'horse_017.jpg', 'human_035.jpg', 'human_021.jpg', 'human_009.jpg', 'human_025.jpg', 'human_031.jpg', 'human_019.jpg', 'horse_013.jpg', 'horse_007.jpg', 'horse_006.jpg', 'horse_012.jpg', 'human_018.jpg', 'human_030.jpg', 'human_024.jpg', 'human_032.jpg', 'human_026.jpg', 'horse_004.jpg', 'horse_010.jpg', 'horse_038.jpg', 'horse_039.jpg', 'horse_011.jpg', 'horse_005.jpg', 'human_027.jpg', 'human_033.jpg', 'human_068.jpg', 'human_054.jpg', 'human_040.jpg', 'human_097.jpg', 'human_083.jpg', 'horse_089.jpg', 'horse_062.jpg', 'horse_076.jpg', 'horse_077.jpg', 'horse_063.jpg', 'horse_088.jpg', 'human_082.jpg', 'human_096.jpg', 'human_041.jpg', 'human_055.jpg', 'human_069.jpg', 'human_043.jpg', 'human_057.jpg', 'human_080.jpg', 'human_094.jpg', 'horse_049.jpg', 'horse_075.jpg', 'horse_061.jpg', 'horse_060.jpg', 'horse_074.jpg', 'horse_048.jpg', 'horse_100.jpg', 'human_095.jpg', 'human_081.jpg', 'human_056.jpg', 'human_042.jpg', 'human_046.jpg', 'human_052.jpg', 'human_085.jpg', 'human_091.jpg', 'horse_070.jpg', 'horse_064.jpg', 'horse_058.jpg', 'horse_059.jpg', 'horse_065.jpg', 'horse_071.jpg', 'human_090.jpg', 'human_084.jpg', 'human_053.jpg', 'human_047.jpg', 'human_051.jpg', 'human_045.jpg', 'human_079.jpg', 'human_092.jpg', 'human_086.jpg', 'horse_098.jpg', 'horse_067.jpg', 'horse_073.jpg', 'horse_072.jpg', 'horse_066.jpg', 'horse_099.jpg', 'human_087.jpg', 'human_093.jpg', 'human_078.jpg', 'human_044.jpg', 'human_050.jpg', 'human_049.jpg', 'human_075.jpg', 'human_061.jpg', 'horse_080.jpg', 'horse_094.jpg', 'horse_043.jpg', 'horse_057.jpg', 'human_100.jpg', 'horse_056.jpg', 'horse_042.jpg', 'horse_095.jpg', 'horse_081.jpg', 'human_060.jpg', 'human_074.jpg', 'human_048.jpg', 'human_062.jpg', 'human_076.jpg', 'human_089.jpg', 'horse_097.jpg', 'horse_083.jpg', 'horse_068.jpg', 'horse_054.jpg', 'horse_040.jpg', 'horse_041.jpg', 'horse_055.jpg', 'horse_069.jpg', 'horse_082.jpg', 'horse_096.jpg', 'human_088.jpg', 'human_077.jpg', 'human_063.jpg', 'human_067.jpg', 'human_073.jpg', 'human_098.jpg', 'horse_092.jpg', 'horse_086.jpg', 'horse_051.jpg', 'horse_045.jpg', 'horse_079.jpg', 'horse_078.jpg', 'horse_044.jpg', 'horse_050.jpg', 'horse_087.jpg', 'horse_093.jpg', 'human_099.jpg', 'human_072.jpg', 'human_066.jpg', 'human_070.jpg', 'human_064.jpg', 'human_058.jpg', 'horse_085.jpg', 'horse_091.jpg', 'horse_046.jpg', 'horse_052.jpg', 'horse_053.jpg', 'horse_047.jpg', 'horse_090.jpg', 'horse_084.jpg', 'human_059.jpg', 'human_065.jpg', 'human_071.jpg', 'human_016.jpg', 'human_002.jpg', 'horse_008.jpg', 'horse_020.jpg', 'horse_034.jpg', 'horse_035.jpg', 'horse_021.jpg', 'horse_009.jpg', 'human_003.jpg', 'human_017.jpg', 'human_029.jpg', 'human_001.jpg', 'human_015.jpg', 'horse_037.jpg', 'horse_023.jpg', 'horse_022.jpg', 'horse_036.jpg', 'human_014.jpg', 'human_028.jpg', 'human_004.jpg', 'human_010.jpg', 'human_038.jpg', 'horse_032.jpg', 'horse_026.jpg', 'horse_027.jpg', 'horse_033.jpg', 'human_039.jpg', 'human_011.jpg', 'human_005.jpg', 'human_013.jpg', 'human_007.jpg', 'horse_025.jpg', 'horse_031.jpg', 'horse_019.jpg', 'horse_018.jpg', 'horse_030.jpg', 'horse_024.jpg', 'human_006.jpg', 'human_012.jpg']
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 642ms/step
# human_037.jpg: 예측 - 사람, 실제 - 사람
# human_023.jpg: 예측 - 사람, 실제 - 사람
# horse_029.jpg: 예측 - 말, 실제 - 말
# horse_001.jpg: 예측 - 말, 실제 - 말
# horse_015.jpg: 예측 - 말, 실제 - 말
# horse_014.jpg: 예측 - 말, 실제 - 말
# horse_028.jpg: 예측 - 말, 실제 - 말
# human_022.jpg: 예측 - 사람, 실제 - 사람
# human_036.jpg: 예측 - 사람, 실제 - 사람
# human_008.jpg: 예측 - 사람, 실제 - 사람
# human_020.jpg: 예측 - 사람, 실제 - 사람
# human_034.jpg: 예측 - 사람, 실제 - 사람
# horse_016.jpg: 예측 - 말, 실제 - 말
# horse_002.jpg: 예측 - 말, 실제 - 말
# horse_003.jpg: 예측 - 말, 실제 - 말
# horse_017.jpg: 예측 - 말, 실제 - 말
# human_035.jpg: 예측 - 사람, 실제 - 사람
# human_021.jpg: 예측 - 사람, 실제 - 사람
# human_009.jpg: 예측 - 사람, 실제 - 사람
# human_025.jpg: 예측 - 사람, 실제 - 사람
# human_031.jpg: 예측 - 사람, 실제 - 사람
# human_019.jpg: 예측 - 사람, 실제 - 사람
# horse_013.jpg: 예측 - 말, 실제 - 말
# horse_007.jpg: 예측 - 말, 실제 - 말
# horse_006.jpg: 예측 - 말, 실제 - 말
# horse_012.jpg: 예측 - 말, 실제 - 말
# human_018.jpg: 예측 - 사람, 실제 - 사람
# human_030.jpg: 예측 - 사람, 실제 - 사람
# human_024.jpg: 예측 - 사람, 실제 - 사람
# human_032.jpg: 예측 - 사람, 실제 - 사람
# human_026.jpg: 예측 - 사람, 실제 - 사람
# horse_004.jpg: 예측 - 말, 실제 - 말
# horse_010.jpg: 예측 - 말, 실제 - 말
# horse_038.jpg: 예측 - 말, 실제 - 말
# horse_039.jpg: 예측 - 말, 실제 - 말
# horse_011.jpg: 예측 - 사람, 실제 - 말
# horse_005.jpg: 예측 - 말, 실제 - 말
# human_027.jpg: 예측 - 사람, 실제 - 사람
# human_033.jpg: 예측 - 사람, 실제 - 사람
# human_068.jpg: 예측 - 사람, 실제 - 사람
# human_054.jpg: 예측 - 사람, 실제 - 사람
# human_040.jpg: 예측 - 사람, 실제 - 사람
# human_097.jpg: 예측 - 사람, 실제 - 사람
# human_083.jpg: 예측 - 사람, 실제 - 사람
# horse_089.jpg: 예측 - 말, 실제 - 말
# horse_062.jpg: 예측 - 말, 실제 - 말
# horse_076.jpg: 예측 - 말, 실제 - 말
# horse_077.jpg: 예측 - 사람, 실제 - 말
# horse_063.jpg: 예측 - 말, 실제 - 말
# horse_088.jpg: 예측 - 말, 실제 - 말
# human_082.jpg: 예측 - 사람, 실제 - 사람
# human_096.jpg: 예측 - 사람, 실제 - 사람
# human_041.jpg: 예측 - 사람, 실제 - 사람
# human_055.jpg: 예측 - 사람, 실제 - 사람
# human_069.jpg: 예측 - 사람, 실제 - 사람
# human_043.jpg: 예측 - 사람, 실제 - 사람
# human_057.jpg: 예측 - 사람, 실제 - 사람
# human_080.jpg: 예측 - 사람, 실제 - 사람
# human_094.jpg: 예측 - 사람, 실제 - 사람
# horse_049.jpg: 예측 - 말, 실제 - 말
# horse_075.jpg: 예측 - 사람, 실제 - 말
# horse_061.jpg: 예측 - 말, 실제 - 말
# horse_060.jpg: 예측 - 말, 실제 - 말
# horse_074.jpg: 예측 - 말, 실제 - 말
# horse_048.jpg: 예측 - 말, 실제 - 말
# horse_100.jpg: 예측 - 말, 실제 - 말
# human_095.jpg: 예측 - 사람, 실제 - 사람
# human_081.jpg: 예측 - 사람, 실제 - 사람
# human_056.jpg: 예측 - 사람, 실제 - 사람
# human_042.jpg: 예측 - 사람, 실제 - 사람
# human_046.jpg: 예측 - 사람, 실제 - 사람
# human_052.jpg: 예측 - 사람, 실제 - 사람
# human_085.jpg: 예측 - 사람, 실제 - 사람
# human_091.jpg: 예측 - 사람, 실제 - 사람
# horse_070.jpg: 예측 - 말, 실제 - 말
# horse_064.jpg: 예측 - 말, 실제 - 말
# horse_058.jpg: 예측 - 말, 실제 - 말
# horse_059.jpg: 예측 - 말, 실제 - 말
# horse_065.jpg: 예측 - 말, 실제 - 말
# horse_071.jpg: 예측 - 사람, 실제 - 말
# human_090.jpg: 예측 - 사람, 실제 - 사람
# human_084.jpg: 예측 - 사람, 실제 - 사람
# human_053.jpg: 예측 - 사람, 실제 - 사람
# human_047.jpg: 예측 - 사람, 실제 - 사람
# human_051.jpg: 예측 - 사람, 실제 - 사람
# human_045.jpg: 예측 - 사람, 실제 - 사람
# human_079.jpg: 예측 - 사람, 실제 - 사람
# human_092.jpg: 예측 - 사람, 실제 - 사람
# human_086.jpg: 예측 - 사람, 실제 - 사람
# horse_098.jpg: 예측 - 말, 실제 - 말
# horse_067.jpg: 예측 - 사람, 실제 - 말
# horse_073.jpg: 예측 - 말, 실제 - 말
# horse_072.jpg: 예측 - 말, 실제 - 말
# horse_066.jpg: 예측 - 말, 실제 - 말
# horse_099.jpg: 예측 - 말, 실제 - 말
# human_087.jpg: 예측 - 사람, 실제 - 사람
# human_093.jpg: 예측 - 사람, 실제 - 사람
# human_078.jpg: 예측 - 사람, 실제 - 사람
# human_044.jpg: 예측 - 사람, 실제 - 사람
# human_050.jpg: 예측 - 사람, 실제 - 사람
# human_049.jpg: 예측 - 사람, 실제 - 사람
# human_075.jpg: 예측 - 사람, 실제 - 사람
# human_061.jpg: 예측 - 사람, 실제 - 사람
# horse_080.jpg: 예측 - 사람, 실제 - 말
# horse_094.jpg: 예측 - 말, 실제 - 말
# horse_043.jpg: 예측 - 사람, 실제 - 말
# horse_057.jpg: 예측 - 말, 실제 - 말
# human_100.jpg: 예측 - 말, 실제 - 사람
# horse_056.jpg: 예측 - 사람, 실제 - 말
# horse_042.jpg: 예측 - 말, 실제 - 말
# horse_095.jpg: 예측 - 말, 실제 - 말
# horse_081.jpg: 예측 - 말, 실제 - 말
# human_060.jpg: 예측 - 사람, 실제 - 사람
# human_074.jpg: 예측 - 사람, 실제 - 사람
# human_048.jpg: 예측 - 사람, 실제 - 사람
# human_062.jpg: 예측 - 사람, 실제 - 사람
# human_076.jpg: 예측 - 사람, 실제 - 사람
# human_089.jpg: 예측 - 사람, 실제 - 사람
# horse_097.jpg: 예측 - 말, 실제 - 말
# horse_083.jpg: 예측 - 말, 실제 - 말
# horse_068.jpg: 예측 - 말, 실제 - 말
# horse_054.jpg: 예측 - 사람, 실제 - 말
# horse_040.jpg: 예측 - 말, 실제 - 말
# horse_041.jpg: 예측 - 말, 실제 - 말
# horse_055.jpg: 예측 - 말, 실제 - 말
# horse_069.jpg: 예측 - 말, 실제 - 말
# horse_082.jpg: 예측 - 말, 실제 - 말
# horse_096.jpg: 예측 - 말, 실제 - 말
# human_088.jpg: 예측 - 사람, 실제 - 사람
# human_077.jpg: 예측 - 사람, 실제 - 사람
# human_063.jpg: 예측 - 사람, 실제 - 사람
# human_067.jpg: 예측 - 사람, 실제 - 사람
# human_073.jpg: 예측 - 사람, 실제 - 사람
# human_098.jpg: 예측 - 사람, 실제 - 사람
# horse_092.jpg: 예측 - 말, 실제 - 말
# horse_086.jpg: 예측 - 말, 실제 - 말
# horse_051.jpg: 예측 - 말, 실제 - 말
# horse_045.jpg: 예측 - 사람, 실제 - 말
# horse_079.jpg: 예측 - 말, 실제 - 말
# horse_078.jpg: 예측 - 말, 실제 - 말
# horse_044.jpg: 예측 - 말, 실제 - 말
# horse_050.jpg: 예측 - 말, 실제 - 말
# horse_087.jpg: 예측 - 말, 실제 - 말
# horse_093.jpg: 예측 - 사람, 실제 - 말
# human_099.jpg: 예측 - 사람, 실제 - 사람
# human_072.jpg: 예측 - 사람, 실제 - 사람
# human_066.jpg: 예측 - 말, 실제 - 사람
# human_070.jpg: 예측 - 사람, 실제 - 사람
# human_064.jpg: 예측 - 사람, 실제 - 사람
# human_058.jpg: 예측 - 사람, 실제 - 사람
# horse_085.jpg: 예측 - 사람, 실제 - 말
# horse_091.jpg: 예측 - 말, 실제 - 말
# horse_046.jpg: 예측 - 말, 실제 - 말
# horse_052.jpg: 예측 - 말, 실제 - 말
# horse_053.jpg: 예측 - 말, 실제 - 말
# horse_047.jpg: 예측 - 사람, 실제 - 말
# horse_090.jpg: 예측 - 말, 실제 - 말
# horse_084.jpg: 예측 - 말, 실제 - 말
# human_059.jpg: 예측 - 말, 실제 - 사람
# human_065.jpg: 예측 - 사람, 실제 - 사람
# human_071.jpg: 예측 - 사람, 실제 - 사람
# human_016.jpg: 예측 - 사람, 실제 - 사람
# human_002.jpg: 예측 - 말, 실제 - 사람
# horse_008.jpg: 예측 - 말, 실제 - 말
# horse_020.jpg: 예측 - 말, 실제 - 말
# horse_034.jpg: 예측 - 말, 실제 - 말
# horse_035.jpg: 예측 - 말, 실제 - 말
# horse_021.jpg: 예측 - 말, 실제 - 말
# horse_009.jpg: 예측 - 말, 실제 - 말
# human_003.jpg: 예측 - 사람, 실제 - 사람
# human_017.jpg: 예측 - 사람, 실제 - 사람
# human_029.jpg: 예측 - 사람, 실제 - 사람
# human_001.jpg: 예측 - 사람, 실제 - 사람
# human_015.jpg: 예측 - 사람, 실제 - 사람
# horse_037.jpg: 예측 - 말, 실제 - 말
# horse_023.jpg: 예측 - 말, 실제 - 말
# horse_022.jpg: 예측 - 말, 실제 - 말
# horse_036.jpg: 예측 - 사람, 실제 - 말
# human_014.jpg: 예측 - 말, 실제 - 사람
# human_028.jpg: 예측 - 사람, 실제 - 사람
# human_004.jpg: 예측 - 사람, 실제 - 사람
# human_010.jpg: 예측 - 사람, 실제 - 사람
# human_038.jpg: 예측 - 사람, 실제 - 사람
# horse_032.jpg: 예측 - 말, 실제 - 말
# horse_026.jpg: 예측 - 사람, 실제 - 말
# horse_027.jpg: 예측 - 말, 실제 - 말
# horse_033.jpg: 예측 - 말, 실제 - 말
# human_039.jpg: 예측 - 사람, 실제 - 사람
# human_011.jpg: 예측 - 말, 실제 - 사람
# human_005.jpg: 예측 - 사람, 실제 - 사람
# human_013.jpg: 예측 - 사람, 실제 - 사람
# human_007.jpg: 예측 - 사람, 실제 - 사람
# horse_025.jpg: 예측 - 말, 실제 - 말
# horse_031.jpg: 예측 - 말, 실제 - 말
# horse_019.jpg: 예측 - 사람, 실제 - 말
# horse_018.jpg: 예측 - 사람, 실제 - 말
# horse_030.jpg: 예측 - 말, 실제 - 말
# horse_024.jpg: 예측 - 사람, 실제 - 말
# human_006.jpg: 예측 - 사람, 실제 - 사람
# human_012.jpg: 예측 - 사람, 실제 - 사람
#
# 전체 맞춘 비율(정확도): 88.00%
