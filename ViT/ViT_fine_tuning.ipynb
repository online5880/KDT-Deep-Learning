# %%
from datasets import load_dataset, load_metric
from PIL import Image
import torch
from transformers import ViTFeatureExtractor, ViTForImageClassification, TrainingArguments,Trainer
import numpy as np

# %%
ds = load_dataset('beans')
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 1034
#     })
#     validation: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 133
#     })
#     test: Dataset({
#         features: ['image_file_path', 'image', 'labels'],
#         num_rows: 128
#     })
# })

# %%
ds['train'][100]
# Out:
# {'image_file_path': '/home/albert/.cache/huggingface/datasets/downloads/extracted/967f0d9f61a7a8de58892c6fab6f02317c06faf3e19fba6a07b0885a9a7142c7/train/angular_leaf_spot/angular_leaf_spot_train.189.jpg',
#  'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>,
#  'labels': 0}

# %%
ds['train'].features['labels']
# Out:
# ClassLabel(names=['angular_leaf_spot', 'bean_rust', 'healthy'], id=None)

# %%
# 이미지 특징 추출 모델 중 하나
from transformers.utils.dummy_vision_objects import ImageGPTFeatureExtractor 

import random
from PIL import ImageDraw,ImageFont, Image

# %%
def show_examples(ds, seed: int = 1234, examples_per_class: int = 3, size=(350, 350)):
    w, h = size
    labels = ds['train'].features['labels'].names
    grid = Image.new('RGB', size=(examples_per_class * w, len(labels) * h))
    draw = ImageDraw.Draw(grid)
    font = ImageFont.truetype("Arial Unicode.ttf", 24)

    for label_id, label in enumerate(labels):

        # 종류별로 데이터를 가져오고, 섞어서 몇 가지 샘플을 보여주도록 합니다
        ds_slice = ds['train'].filter(lambda ex: ex['labels'] == label_id).shuffle(seed).select(range(examples_per_class))

        # 각 행을 따라 시각화합니다
        for i, example in enumerate(ds_slice):
            image = example['image']
            idx = examples_per_class * label_id + i
            box = (idx % examples_per_class * w, idx // examples_per_class * h)
            grid.paste(image.resize(size), box=box)
            draw.text(box, label, (255, 255, 255), font=font)

    return grid

show_examples(ds, seed=random.randint(0, 1337), examples_per_class=3)
# Out:
# <PIL.Image.Image image mode=RGB size=1050x1050>

# %%
model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
def process_example(example):
    inputs = feature_extractor(example['image'],return_tensors='pt')
    inputs['label'] = example['labels']
    return inputs

# %%
process_example(ds['train'][0])
# Out:
# {'pixel_values': tensor([[[[-0.5686, -0.5686, -0.5608,  ..., -0.0275,  0.1922, -0.2549],
#           [-0.6078, -0.6000, -0.5843,  ..., -0.0353, -0.0196, -0.2706],
#           [-0.6314, -0.6314, -0.6157,  ..., -0.2392, -0.3647, -0.2314],
#           ...,
#           [-0.5373, -0.5529, -0.5765,  ..., -0.0745, -0.0431, -0.0980],
#           [-0.5608, -0.5765, -0.5843,  ...,  0.3176,  0.1608,  0.1294],
#           [-0.5843, -0.5922, -0.6078,  ...,  0.2784,  0.1451,  0.2000]],
#
#          [[-0.7098, -0.7098, -0.7490,  ..., -0.3725, -0.1608, -0.6000],
#           [-0.7333, -0.7333, -0.7569,  ..., -0.3569, -0.3176, -0.5608],
#           [-0.7490, -0.7490, -0.7647,  ..., -0.5373, -0.6627, -0.5373],
#           ...,
#           [-0.7725, -0.7882, -0.8196,  ..., -0.2314, -0.0353,  0.0824],
#           [-0.7961, -0.8118, -0.8118,  ...,  0.1843,  0.3176,  0.3725],
#           [-0.8196, -0.8196, -0.8275,  ...,  0.0745,  0.2863,  0.3961]],
#
#          [[-0.9922, -0.9922, -1.0000,  ..., -0.5451, -0.3647, -0.7333],
#           [-0.9922, -0.9922, -1.0000,  ..., -0.5686, -0.5451, -0.7176],
#           [-0.9843, -0.9922, -1.0000,  ..., -0.6549, -0.7490, -0.6314],
#           ...,
#           [-0.8431, -0.8588, -0.8980,  ..., -0.5765, -0.5608, -0.5529],
#           [-0.8588, -0.8902, -0.9137,  ..., -0.2078, -0.2549, -0.2706],
#           [-0.8824, -0.9059, -0.9294,  ..., -0.2627, -0.1922, -0.1216]]]]), 'label': 0}

# %%
def transform(example_batch):
    inputs = feature_extractor([x for x in example_batch['image']],return_tensors='pt')
    inputs['labels'] = example_batch['labels']
    return inputs

# %%
prepared_ds = ds.with_transform(transform)

# %%
prepared_ds['train'][0]
# Out:
# {'pixel_values': tensor([[[-0.5686, -0.5686, -0.5608,  ..., -0.0275,  0.1922, -0.2549],
#           [-0.6078, -0.6000, -0.5843,  ..., -0.0353, -0.0196, -0.2706],
#           [-0.6314, -0.6314, -0.6157,  ..., -0.2392, -0.3647, -0.2314],
#           ...,
#           [-0.5373, -0.5529, -0.5765,  ..., -0.0745, -0.0431, -0.0980],
#           [-0.5608, -0.5765, -0.5843,  ...,  0.3176,  0.1608,  0.1294],
#           [-0.5843, -0.5922, -0.6078,  ...,  0.2784,  0.1451,  0.2000]],
#
#          [[-0.7098, -0.7098, -0.7490,  ..., -0.3725, -0.1608, -0.6000],
#           [-0.7333, -0.7333, -0.7569,  ..., -0.3569, -0.3176, -0.5608],
#           [-0.7490, -0.7490, -0.7647,  ..., -0.5373, -0.6627, -0.5373],
#           ...,
#           [-0.7725, -0.7882, -0.8196,  ..., -0.2314, -0.0353,  0.0824],
#           [-0.7961, -0.8118, -0.8118,  ...,  0.1843,  0.3176,  0.3725],
#           [-0.8196, -0.8196, -0.8275,  ...,  0.0745,  0.2863,  0.3961]],
#
#          [[-0.9922, -0.9922, -1.0000,  ..., -0.5451, -0.3647, -0.7333],
#           [-0.9922, -0.9922, -1.0000,  ..., -0.5686, -0.5451, -0.7176],
#           [-0.9843, -0.9922, -1.0000,  ..., -0.6549, -0.7490, -0.6314],
#           ...,
#           [-0.8431, -0.8588, -0.8980,  ..., -0.5765, -0.5608, -0.5529],
#           [-0.8588, -0.8902, -0.9137,  ..., -0.2078, -0.2549, -0.2706],
#           [-0.8824, -0.9059, -0.9294,  ..., -0.2627, -0.1922, -0.1216]]]),
#  'labels': 0}

# %%
def collate_fn(batch):
    return {
        'pixel_values':torch.stack([x['pixel_values'] for x in batch]),
        'labels':torch.tensor([x['labels'] for x in batch])
    }

# %%
metric = load_metric('accuracy',trust_remote_code=True)

def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)
# Out:
# /var/folders/dn/kpsvhr056zz6gvcnmgrkklzr0000gn/T/ipykernel_19120/684330436.py:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric('accuracy',trust_remote_code=True)

# %%
labels = ds['train'].features['labels'].names

# %%
model = ViTForImageClassification.from_pretrained(
    model_name_or_path,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)}
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir='./',
    per_device_train_batch_size=16,
    eval_strategy='steps',
    num_train_epochs=2,
    fp16=False, # 16비트 부동소수점을 사용할 것인가
    save_steps=100,
    eval_steps=100,
    logging_steps=10,
    learning_rate=0.01,
    save_total_limit=2,
    remove_unused_columns=False,
    push_to_hub=False,
    report_to='tensorboard',
    load_best_model_at_end=True
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    train_dataset=prepared_ds["train"],
    eval_dataset=prepared_ds["validation"],
    tokenizer=feature_extractor,
)

# %%
train_results = trainer.train()
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
#   0%|          | 0/130 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 train_results = trainer.train()
#       2 trainer.save_model()
#       3 trainer.log_metrics("train", train_results.metrics)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/trainer.py:1938, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1936         hf_hub_utils.enable_progress_bars()
#    1937 else:
# -> 1938     return inner_training_loop(
#    1939         args=args,
#    1940         resume_from_checkpoint=resume_from_checkpoint,
#    1941         trial=trial,
#    1942         ignore_keys_for_eval=ignore_keys_for_eval,
#    1943     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/trainer.py:2341, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2338     else:
#    2339         grad_norm = _grad_norm
# -> 2341 self.optimizer.step()
#    2343 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2345 optimizer_was_run = not self.accelerator.optimizer_step_was_skipped
#
# File /opt/anaconda3/lib/python3.12/site-packages/accelerate/optimizer.py:172, in AcceleratedOptimizer.step(self, closure)
#     170         self._accelerate_step_called = False
#     171     else:
# --> 172         self.optimizer.step(closure)
#     173 if self.accelerator_state.distributed_type == DistributedType.XLA:
#     174     self.gradient_state.is_xla_gradients_synced = False
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:130, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     128 opt = opt_ref()
#     129 opt._opt_called = True  # type: ignore[union-attr]
# --> 130 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/adamw.py:227, in AdamW.step(self, closure)
#     214     beta1, beta2 = cast(Tuple[float, float], group["betas"])
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     224         state_steps,
#     225     )
# --> 227     adamw(
#     228         params_with_grad,
#     229         grads,
#     230         exp_avgs,
#     231         exp_avg_sqs,
#     232         max_exp_avg_sqs,
#     233         state_steps,
#     234         amsgrad=amsgrad,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247         has_complex=has_complex,
#     248     )
#     250 return loss
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/adamw.py:767, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     764 else:
#     765     func = _single_tensor_adamw
# --> 767 func(
#     768     params,
#     769     grads,
#     770     exp_avgs,
#     771     exp_avg_sqs,
#     772     max_exp_avg_sqs,
#     773     state_steps,
#     774     amsgrad=amsgrad,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785     has_complex=has_complex,
#     786 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/optim/adamw.py:377, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     374 step_t += 1
#     376 # Perform stepweight decay
# --> 377 param.mul_(1 - lr * weight_decay)
#     379 # Decay the first and second moment running average coefficient
#     380 exp_avg.lerp_(grad, 1 - beta1)
#
# KeyboardInterrupt:
